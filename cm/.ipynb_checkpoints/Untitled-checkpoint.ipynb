# %%
import numpy as np
import matplotlib.pyplot as plt

n=60
x=np.random.randint(1,100,n)
y=np.random.randint(1,100,n)


x_c=np.mean(x)
y_c=np.mean(y)



def dist(x1,y1,x2,y2):
    return np.sqrt((x1-x2)**2+(y1-y2)**2)



def c_means(k,max_iter):    
    m, eps=2, 0.2
    u=np.zeros([n,k])
    u_new=np.zeros([n,k])
    mu=[0]*n
    u_sum=[0]*n
    
    def check(x,y,clust,k):
        for i in range(0,len(clust)):
            for j in range(0,k):
                if(clust[i]==j):
                    u[i][j]=1
                else:
                    u[i][j]=0

    def clusters(x_cc,y_cc,x,y):
        for i in range(0,n):
            r=dist(x_cc[0],y_cc[0],x[i],y[i])
            numb=0
            for j in range(0,k):
                if(r<dist(x_cc[j],y_cc[j],x[i],y[i])):
                    numb=j
                    r=dist(x_cc[j],y_cc[j],x[i],y[i])
                if(j==k-1):
                    clust[i]=numb

    
    R=0
    for i in range(0,n):
        if(dist(x_c,y_c,x[i],y[i])>R):
            R=dist(x_c,y_c,x[i],y[i])

    x_cc=[R*np.cos(2*np.pi*i/k)+x_c for i in range(k)]
    y_cc=[R*np.sin(2*np.pi*i/k)+y_c for i in range(k)]


    clust=[0]*n


   # clusters(x_cc,y_cc,x,y)
   # draw(x,y,clust,x_cc,y_cc,k)
   # check(x,y,clust,k)

    u = np.random.dirichlet(np.ones(k),size=n)
    print(np.round(u,2))
        
    x_cc=[0]*n
    y_cc=[0]*n
            
    for dik in range(0,max_iter):
        for i in range(0,n):
            for j in range(0,k):
                u_sum[i]+=u[i][j]
                
        downSum=0
        upSum=0
        
        for i in range(0,k)
            for j in range(0,n):  
                downSum+=(u_sum[j])**m
                upSum+=(u[j]*((u_sum[j])**m))
            x_cc[i]=upSum/downSum
            y_cc[i]=(u[j]*((u_sum[j])**m))/(u_sum[j])**m       
                
        for i in range(0,n):
            for j in range(0,k):
                sum=0
                for l in range(0,k):
                    sum+=(dist(x_cc[j],y_cc[j],x[i],y[i])/dist(x_cc[l],y_cc[l],x[i],y[i]))**(2/(m-1))
                u_new[i][j]=1/sum
                
      #  for i in range(0,n):
   # for j in range(0,k):
      #  for e in range(0,k):
     #       u_new[i][j]+=dist(x_cc[j], y_cc[j],x[i],y[i])/dist(x_cc[e],y_cc[e],x[i],y[i])
    #for j in range(0,k):
        #u_new[i][j]=(1/u_new[i][j])**(2/m-1)        


        bool=True
        for i in range(0,n):
            for j in range(0,k):
                if(bool==True and (u[i][j]-u_new[i][j])>=eps):
                    u[i][j]=u_new[i][j]
                    continue
                else:
                    bool=False
                    break
        if(bool==True):
            max_iter=49
            break
    
    
c_means(4,50)
# Out:
# [[0.66 0.04 0.25 0.05]
#  [0.41 0.42 0.17 0.  ]
#  [0.09 0.54 0.07 0.3 ]
#  [0.47 0.36 0.01 0.17]
#  [0.06 0.48 0.29 0.17]
#  [0.09 0.29 0.01 0.61]
#  [0.57 0.17 0.19 0.08]
#  [0.03 0.24 0.49 0.24]
#  [0.12 0.27 0.2  0.41]
#  [0.07 0.84 0.06 0.04]
#  [0.75 0.09 0.06 0.11]
#  [0.23 0.37 0.22 0.18]
#  [0.1  0.3  0.26 0.33]
#  [0.11 0.08 0.23 0.57]
#  [0.32 0.55 0.06 0.06]
#  [0.02 0.58 0.05 0.34]
#  [0.19 0.4  0.05 0.36]
#  [0.8  0.15 0.03 0.02]
#  [0.55 0.1  0.26 0.09]
#  [0.39 0.08 0.45 0.08]
#  [0.23 0.07 0.52 0.17]
#  [0.08 0.82 0.02 0.08]
#  [0.35 0.55 0.08 0.01]
#  [0.05 0.47 0.29 0.19]
#  [0.05 0.21 0.58 0.16]
#  [0.23 0.36 0.16 0.25]
#  [0.13 0.22 0.17 0.48]
#  [0.56 0.14 0.16 0.13]
#  [0.41 0.31 0.13 0.14]
#  [0.15 0.64 0.06 0.14]
#  [0.49 0.3  0.09 0.13]
#  [0.08 0.36 0.04 0.51]
#  [0.1  0.67 0.06 0.17]
#  [0.37 0.54 0.03 0.06]
#  [0.49 0.41 0.09 0.02]
#  [0.29 0.46 0.09 0.16]
#  [0.38 0.21 0.25 0.15]
#  [0.34 0.03 0.53 0.1 ]
#  [0.15 0.62 0.08 0.16]
#  [0.32 0.5  0.12 0.06]
#  [0.01 0.27 0.09 0.64]
#  [0.09 0.33 0.02 0.56]
#  [0.2  0.28 0.42 0.11]
#  [0.28 0.16 0.41 0.15]
#  [0.24 0.09 0.07 0.6 ]
#  [0.44 0.16 0.24 0.16]
#  [0.33 0.31 0.15 0.21]
#  [0.18 0.08 0.69 0.05]
#  [0.35 0.21 0.26 0.18]
#  [0.4  0.02 0.47 0.11]
#  [0.31 0.48 0.06 0.15]
#  [0.09 0.59 0.16 0.17]
#  [0.32 0.19 0.4  0.09]
#  [0.02 0.25 0.34 0.39]
#  [0.4  0.32 0.05 0.23]
#  [0.27 0.01 0.28 0.45]
#  [0.51 0.03 0.29 0.17]
#  [0.3  0.11 0.26 0.33]
#  [0.21 0.21 0.47 0.11]
#  [0.02 0.03 0.85 0.1 ]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-fcefafd37dea> in <module>
#     102
#     103
# --> 104 c_means(4,50)
#     105
#     106
#
# <ipython-input-6-fcefafd37dea> in c_means(k, max_iter)
#      70
#      71         for i in range(0,n):
# ---> 72             x_cc[i]=(x[i]*(u_sum[i])**m)/(u_sum[i])**m
#      73             y_cc[i]=(y[i]*(u_sum[i])**m)/(u_sum[i])**m
#      74
#
# IndexError: list assignment index out of range
